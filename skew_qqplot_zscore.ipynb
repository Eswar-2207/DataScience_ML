# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
h=pd.read_excel("Employees.xlsx")
h
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
hn=h[['No','Department','Monthly Salary']]
hn
# Out:
#       No              Department  Monthly Salary
# 0      1         Quality Control            1560
# 1      2         Quality Control            3247
# 2      3      Major Mfg Projects            2506
# 3      4           Manufacturing            1828
# 4      5           Manufacturing             970
# ..   ...                     ...             ...
# 684  685               Marketing            1452
# 685  686  Facilities/Engineering            3237
# 686  687  Facilities/Engineering            2819
# 687  688                Creative            2069
# 688  689                      IT            2606
#
# [689 rows x 3 columns]

# %%
from scipy.stats import skew
skew(h['Monthly Salary'])
# Out:
# np.float64(0.003230530463503725)

# %%
m=skew(hn['Monthly Salary'])
m
# Out:
# np.float64(0.003230530463503725)

# %%
np.mean(m)
# Out:
# np.float64(0.003230530463503725)

# %%
np.median(m)
# Out:
# np.float64(0.003230530463503725)

# %%
plt.hist(hn['Monthly Salary'])
plt.show()

# %%
p=pd.read_csv('data.csv')
p
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
skew(p['price'])
# Out:
# np.float64(24.78284782965085)

# %%
import statsmodels.api as sm
sm.qqplot(p['price'],line='45')
plt.show()

# %%
c=pd.read_csv('transactions.csv')
c
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          8  CASH_OUT  158007.12   C424875646           0.00            0.00
# 1        236  CASH_OUT  457948.30  C1342616552           0.00            0.00
# 2         37   CASH_IN  153602.99   C900876541    11160428.67     11314031.67
# 3        331  CASH_OUT   49555.14   C177696810       10865.00            0.00
# 4        250  CASH_OUT   29648.02   C788941490           0.00            0.00
# ...      ...       ...        ...          ...            ...             ...
# 199994   201   PAYMENT    1274.97   C361372882       69376.00        68101.03
# 199995   212  CASH_OUT  204041.98  C1621547576       40423.00            0.00
# 199996   160   CASH_IN   66378.61  C1431532774     2852895.88      2919274.49
# 199997    12   CASH_IN   87473.93   C695681900     1674588.27      1762062.20
# 199998    15  CASH_OUT   97305.08   C809605956       21328.00            0.00
#
# ...

# %%
skew(c['amount'])
# Out:
# np.float64(30.78782778743495)

# %%
import scipy.stats as s
s.zscore(c['amount'])
# Out:
# array([-0.0355455 ,  0.443941  , -0.04258595, ..., -0.18202299,
#        -0.14829998, -0.13258389], shape=(199999,))
